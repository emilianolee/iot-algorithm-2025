# %%
# 변수 선언
maxWeight = 7
rowCount = 4
weight = [0, 6, 4, 3, 5] # 보석무게
money = [0, 13, 8, 6, 12] # 보석가격

def knapsack():
    array = [[0 for _ in range(maxWeight+1)] for _ in range(rowCount+1)]    
    for row in range(1, rowCount+1):
        for col in range(1, maxWeight+1): # 보석개수
            if weight[row] > col: # 보석의 무게가 무거워서 가방에 못 들어가면
                array[row][col] = array[row -1][col]
            else: # 보석의 무게가 가방무게보다 작거나 같으면
                value1= money[row] + array[row -1][col-weight[row]]  # 현재보석 가치와 배낭무게에서 현재보석의 무게를 뺀 위치의 가치를 합산 결과
                value2 = array[row -1][col]
                array[row][col] = max(value1, value2)
    
    return array[rowCount][maxWeight] # 최종결과값

# 메인로직
maxValue = knapsack()
print()
print(f'배낭에 당을 수 있는 보석의 최대 가격 --> {maxValue}억원')
# Out:
# 배낭에 당을 수 있는 보석의 최대 가격 --> 14억원

# %%
# 함수 선언
def isQueueFull(): # 큐가 찼는지 확인
    global SIZE, queue, front, rear
    if (rear == SIZE-1):
        return True
    else:
        return False

def isQueueEmpty(): # 큐가 비었는지 확인
    global SIZE, queue, front, rear
    if front == rear:
        return True
    else:
        return False

def enQueue(data): # 큐가 안찼으면 데이터 삽입
    global SIZE, queue, front, rear
    if isQueueFull():
        print('큐가 꽉 찼습니다.')
        return
    else:
        rear += 1
        queue[rear] = data

def deQueue(): # 큐가 안비었으면 데이터 추출
    global SIZE, queue, front, rear
    if isQueueEmpty():
        print('큐가 비었습니다.')
        return None
    else:
        front += 1
        data = queue[front]
        queue[front] = None
    
    for i in range(front + 1, rear + 1): # 모든 사람을 한 칸씩 앞으로 당김
        queue[i-1] = queue[i] # 데이터 앞 빈자리에 첫번째 데이터를 옮김
        queue[i] = None
    front = -1
    rear -= 1
    
    return data

def peek(): # 추출될 데이터 확인
    global SIZE, queue, front, rear
    if isQueueEmpty():
        print('큐가 비었습니다.')
        return None
    else:
        return queue[front + 1]

# 전역 변수 선언
SIZE = 5
queue = [None for _ in range(SIZE)]
front = rear = -1

# 메인코드
if __name__ == '__main__':
    while True:
        select = input('삽입(I)/추출(E)/확인(V)/종료(Q) --> ').upper()

        if select == 'Q':
            break
        elif select == 'I':
            data = input('데이터 입력 > ')
            enQueue(data)
            print(f'대기 줄 상태 : {queue}')
        elif select == 'E':
            data = deQueue()
            print(f'{data}님 식당에 들어감')
            print(f'대기 줄 상태 : {queue}')
        elif select == 'V':
            data = peek()
            print(f'{data}님은 다음 입장 순서입니다.')
            print(f'대기 줄 상태 : {queue}')
        else:
            print('입력 오류')

    print("식당 영업 종료")
# Out:
# 대기 줄 상태 : ['진', None, None, None, None]
# 대기 줄 상태 : ['진', '슈가', None, None, None]
# 대기 줄 상태 : ['진', '슈가', '뷔', None, None]
# 대기 줄 상태 : ['진', '슈가', '뷔', '지민', None]
# 대기 줄 상태 : ['진', '슈가', '뷔', '지민', '정국']
# 진은 다음 입장 순서입니다.
# 대기 줄 상태 : ['진', '슈가', '뷔', '지민', '정국']
# 진은 다음 입장 순서입니다.
# 대기 줄 상태 : ['진', '슈가', '뷔', '지민', '정국']
# 진은 다음 입장 순서입니다.
# 대기 줄 상태 : ['진', '슈가', '뷔', '지민', '정국']
# 진님 식당에 들어감
# 대기 줄 상태 : ['슈가', '뷔', '지민', '정국', None]
# 슈가은 다음 입장 순서입니다.
# 대기 줄 상태 : ['슈가', '뷔', '지민', '정국', None]
# 슈가은 다음 입장 순서입니다.
# 대기 줄 상태 : ['슈가', '뷔', '지민', '정국', None]
# 슈가은 다음 입장 순서입니다.
# 대기 줄 상태 : ['슈가', '뷔', '지민', '정국', None]
# 슈가님 식당에 들어감
# 대기 줄 상태 : ['뷔', '지민', '정국', None, None]
# 식당 영업 종료

# %%
import random
# TreeNode 클래스 선언
class TreeNode():
    def __init__(self):
        self.left = None
        self.data = None
        self.right = None

# 전역 변수 선언
memory = []
root = None
dataAry= ['콘말차', '삿포로 맥주', '아카페라 벤티 헤이즐넛', '레어치즈푸딩', 
          '척오리지널 메가 사워', '요아정 요거트컵', '페퍼로니피자주먹밥', '널담 슈톨렌', 
          '딸기마시멜로케이크', '버니공쥬 딸기뚱카롱', '고추잡채호빵', '체다 슈크림붕어스낵']
sellAry = []

while True:
    select = input('삽입(I)/종료(Q) --> ').upper()

    if select == 'Q':
        break
    elif select == 'I':
        data = input('판매된 물건을 입력하세요 --> ')
        if data in dataAry:
            sellAry.append(data)
            print(f'판매된 물건 리스트 : {sellAry}')
        else:
            print('해당 물건은 편의점에 존재하지 않습니다.')
    else:
        print('입력 오류')

print(f'오늘 판매된 물건(중복O) --> {sellAry}')

# 메인 코드
node = TreeNode()
node.data = sellAry[0]
root = node
memory.append(node)

for name in sellAry[1:]:
        
    node = TreeNode()
    node.data = name

    current = root
    while True:
        if name == current.data:
            break
        if name < current.data: # 현재 name인 노드 안 데이터보다 작으면, 왼쪽으로
            if current.left == None:
                current.left == node
                memory.append(node)
                break # 연결했으니까 반복문 탈출
            else: 
                current = current.left # 왼쪽으로 더 내려감
        else:  # 오른쪽으로 보냄
            if current.right == None:
                current.right = node
                memory.append(node)
                break
            else:
                current = current.right

print('이진트리 구성 완료!')

# 전위순회 함수 정의
def preorder(node):
    if node == None:
        return
    print(node.data, end=' ')
    preorder(node.left)
    preorder(node.right)

print('오늘 판매된 종류(중복X) --> ', end=' ')
preorder(root)
# Out:
# 판매된 물건 리스트 : ['콘말차']
# 판매된 물건 리스트 : ['콘말차', '고추잡채호빵']
# 판매된 물건 리스트 : ['콘말차', '고추잡채호빵', '레어치즈푸딩']
# 오늘 판매된 물건(중복O) --> ['콘말차', '고추잡채호빵', '레어치즈푸딩']
# 이진트리 구성 완료!
# 오늘 판매된 종류(중복X) -->  콘말차

# %%
import random

# 함수 선언
def binSearch(ary, data):
    global count
    pos = -1
    start = 0
    end = len(ary) - 1 # 리스트 마지막 인덱스

    while start <= end: # 시작이 끝보다 커지면 검색 실패
        count += 1 
        mid = (start + end) // 2

        if data == ary[mid]:
            return mid
        elif data > ary[mid]:
            start = mid + 1 # 뒤쪽에 데이터가 있다.
        else: 
            end = mid - 1 # 앞쪽에 데이터가 있다.
    
    return pos

# 변수
dataAry, sortedAry = [], []
findData = random.randint(0,100000) # 0 ~ 100000 중 무작위 수 추출
count = 0

dataAry = [random.randint(0,100000) for _ in range(100001)] # 데이터 100000만개 생성
dataAry.insert(random.randint(0, 100000), findData) # 랜덤한 위치에 배치
sortedAry = sorted(dataAry) # 데이터 정렬

print(f'배열일부 -> {sortedAry[0:5]} ~~~~ {sortedAry[-5:len(sortedAry)]}') # 배열 앞 뒤 5개씩 출력

count = 0
pos = binSearch(sortedAry, findData)
if pos == -1:
    print(f'{findData} (이)가 없네요')
    print(f'## {count}회 검색함')
else:
    print(f'{findData}(은)는 {pos} 위치에 있음')
    print(f'## {count}회 검색함')
# Out:
# 배열일부 -> [1, 2, 2, 3, 3] ~~~~ [99995, 99995, 99996, 99996, 100000]
# 63712(은)는 63768 위치에 있음
# ## 10회 검색함
